# %% [markdown]
# # [VISUALIZATION USING HISTOGRAM]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset into pandas dataframe
data = pd.read_csv('Iris.csv')

# %%
data   #display dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.iloc[0][0:5].plot(kind='bar',color='blue')
# Out:
# <Axes: >

# %%
#load datasets
dataset=pd.read_csv('Iris.csv')
Id=dataset['Id']
SepalLengthCm=dataset['SepalLengthCm']
SepalWidthCm=dataset['SepalWidthCm']
PetalLengthCm=dataset['PetalLengthCm']
PetalWidthCm=dataset['PetalWidthCm']
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# plotting Histogram
plt.hist(SepalLengthCm,bins=10,alpha=0.9,rwidth=0.8,color='blue',label='SepalLengthCm')
plt.hist(SepalWidthCm,bins=10,alpha=0.9,rwidth=0.8,color='orange',label='SepalWidthCm')
plt.hist(PetalLengthCm,bins=10,alpha=0.9,rwidth=0.8,color='green',label='PetalLengthCm')
plt.hist(PetalWidthCm,bins=10,alpha=0.9,rwidth=0.8,color='yellow',label='PetalWidthCm')
plt.legend()

# %%
plt.figure(figsize=(5,5))
s=data['SepalLengthCm']
plt.hist(s,bins=25,color='blue',alpha=0.7)
plt.title('Sepal Length in Cm')
plt.xlabel('sepal_Length_Cm')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize=(5,5))
t=data['SepalWidthCm']
plt.hist(t,bins=25,color='orange',alpha=0.4)
plt.title('Sepal Width in Cm')
plt.xlabel('sepal_Width_Cm')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize=(5,5))
t=data['PetalLengthCm']
plt.hist(t,bins=25,color='green',alpha=0.9)
plt.title('Petal Length in Cm')
plt.xlabel('Petal_Length_Cm')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize=(5,5))
t=data['PetalWidthCm']
plt.hist(t,bins= 25,color= 'yellow',alpha= 0.8)
plt.title('Petal Width in Cm')
plt.xlabel('Petal_Width_Cm')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
data.hist(figsize=(10,10), color='cyan',alpha=0.7)
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %%
data.plot.scatter(x='SepalLengthCm',y='PetalLengthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
data.plot.scatter(x='SepalWidthCm',y='PetalWidthCm')
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='PetalWidthCm'>

# %%
sns.pairplot(data)

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
#joint plot using seaborn(scatterplot and histogram)

sns.jointplot(x = 'SepalLengthCm',y='PetalLengthCm',data=data)

# %%
sns.jointplot(x='SepalWidthCm',y='PetalWidthCm',data=data)

# %%
sns.jointplot(x = 'SepalLengthCm',y='PetalLengthCm',data=data,kind='reg')

# %%
sns.jointplot(x='SepalWidthCm',y='PetalWidthCm',data=data,kind='reg')
